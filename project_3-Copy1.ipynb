# %% [markdown]
# ### Table of Contents
# - [Introduction](#introduction)
# - [1. Loading dataset and libraries](#loading)
# - [2. Preprocessing](#preprocessing)
#     - [2.1 Rename columns](#rename-columns)
#     - [2.2 Data types](#data-types)
#     - [2.2 Missing values](#missing-values)
#     - [2.3 Duplicated data](#duplicated-data)
# - [3. Statistical description](#statistical)
#     - [3.1 Description](#description)
#     - [3.2 Scatter Plots, Clustering and Data Exploration](#exploration)
#     - [3.3 Correlation Heatmap](#correlation)
# - [4. Models](#models)
#     - [4.1 Standardization and splitting](#standardization)
#     - [4.2 Model Zero](#model-0)
#     - [4.3 Grid Search](#grid)

# %% [markdown]
# ## Introduction <a name="introduction" />
# ### Danijel Sokolovic
# ### Indeks: 1392
#
# ### Energy efficiency
# ### Features
# 1. **X1 - A - Relative Compactness**\
# This value is obtained by the sum of all surfaces of its envelope, divided by its gross heated volume.\
# The Rc of a shape is derived in that its volume to surface ratio is compared to that of the most compact shape with the same volume.
# 2. X2 - B - Surface Area
# 3. X3 - C - Wall Area
# 4. X4 - D - Roof Area
# 5. X5 - E - Overall Height
# 6. X6 - F - Orientation
# 7. X7 - G - Glazing Area
# 8. X8 - H - Glazing Area Distribution
#
# ### Output (target values)
# - y1 Heating Load
# - y2 Cooling Load

# %% [markdown]
# ## 1. Loading dataset and libraries <a name="loading" />

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import collections
from pprint import pprint
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from numpy import mean
from numpy import std
from numpy import absolute
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import RepeatedKFold
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

df = pd.read_csv("en_eff.csv")
df.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28

# %%
df.shape
# Out:
# (768, 10)

# %% [markdown]
# Vidimo da imamo 768 rows i 10 columns, features, sto se uklapa sa opisom dataseta.

# %% [markdown]
# ## 2. Preprocessing <a name="preprocessing"/>

# %% [markdown]
# ### 2.1 Rename columns  <a name="rename-columns"/>

# %%
df.columns = ['relative_compactness', 
              'surface_area', 
              'wall_area', 
              'roof_area', 
              'overall_height', 
              'orientation', 
              'glazing_area', 
              'glazing_distribution', 
              'heating_load', 
              'cooling_load']
df.head()
# Out:
#    relative_compactness  surface_area  wall_area  roof_area  overall_height  \
# 0                  0.98         514.5      294.0     110.25             7.0
# 1                  0.98         514.5      294.0     110.25             7.0
# 2                  0.98         514.5      294.0     110.25             7.0
# 3                  0.98         514.5      294.0     110.25             7.0
# 4                  0.90         563.5      318.5     122.50             7.0
#
#    orientation  glazing_area  glazing_distribution  heating_load  cooling_load
# 0            2           0.0                     0         15.55         21.33
# 1            3           0.0                     0         15.55         21.33
# 2            4           0.0                     0         15.55         21.33
# 3            5           0.0                     0         15.55         21.33
# 4            2           0.0                     0         20.84         28.28

# %% [markdown]
# ### 2.2 Data types  <a name="data-types"/>

# %%
df.dtypes
# Out:
# relative_compactness    float64
# surface_area            float64
# wall_area               float64
# roof_area               float64
# overall_height          float64
# orientation               int64
# glazing_area            float64
# glazing_distribution      int64
# heating_load            float64
# cooling_load            float64
# dtype: object

# %% [markdown]
# Potvrdjujemo da se radi samo sa brojevima, realni i celi brojevi.

# %% [markdown]
# ### 2.3 Missing values  <a name="missing-values"/>

# %%
df.isnull().any()
# Out:
# relative_compactness    False
# surface_area            False
# wall_area               False
# roof_area               False
# overall_height          False
# orientation             False
# glazing_area            False
# glazing_distribution    False
# heating_load            False
# cooling_load            False
# dtype: bool

# %% [markdown]
# Proveravamo da li ima nekih NaN vrednosti. Zakljucak je da nema takvih vrednosti.

# %% [markdown]
# ### 2.3 Duplicated data  <a name="duplicated-data"/>

# %%
duplicates = df.duplicated().sum()
duplicates
# Out:
# 0

# %% [markdown]
# Proveravamo da li ima nekih duplih vrednosti, misli se na duplirane redove. Zakljucak je da nema dupliranih redova u datasetu.

# %% [markdown]
# ## 3. Statistical Description  <a name="statistical"/>

# %% [markdown]
# ### 3.1 Description <a name="description"/>

# %%
df.describe()
# Out:
#        relative_compactness  surface_area   wall_area   roof_area  \
# count            768.000000    768.000000  768.000000  768.000000
# mean               0.764167    671.708333  318.500000  176.604167
# std                0.105777     88.086116   43.626481   45.165950
# min                0.620000    514.500000  245.000000  110.250000
# 25%                0.682500    606.375000  294.000000  140.875000
# 50%                0.750000    673.750000  318.500000  183.750000
# 75%                0.830000    741.125000  343.000000  220.500000
# max                0.980000    808.500000  416.500000  220.500000
#
#        overall_height  orientation  glazing_area  glazing_distribution  \
# count       768.00000   768.000000    768.000000             768.00000
# mean          5.25000     3.500000      0.234375               2.81250
# std           1.75114     1.118763      0.133221               1.55096
# min           3.50000     2.000000      0.000000               0.00000
# 25%           3.50000     2.750000      0.100000               1.75000
# 50%           5.25000     3.500000      0.250000               3.00000
# 75%           7.00000     4.250000      0.400000               4.00000
# max           7.00000     5.000000      0.400000               5.00000
#
#        heating_load  cooling_load
# count    768.000000    768.000000
# mean      22.307201     24.587760
# std       10.090196      9.513306
# min        6.010000     10.900000
# 25%       12.992500     15.620000
# 50%       18.950000     22.080000
# 75%       31.667500     33.132500
# max       43.100000     48.030000

# %% [markdown]
# Moze se primetiti da **max** vrednost za **heating_load** i **cooling_load** ne prelazi **50**. Takodje, **orientation** je izmedju vrednosti **2** i **5** (inkluzivno).\
# **glazing_area**, **glazing_distribution**, **relative_compactness**, **overal_height** i **orientation** imaju veoma male vrednosti u odnosu na ostale.

# %% [markdown]
# ### 3.2 Scatter Plots, Clustering and Data Exploration  <a name="exploration"/>

# %% [markdown]
# Uzimamo oba output-a, heating_load i cooling_load, u zavisnosti od prvog featur-a, relative_compactness.

# %%
plt.scatter(df.relative_compactness, df.heating_load, label='heating_load')
plt.scatter(df.relative_compactness, df.cooling_load, label='cooling_load')

plt.title('Scatterplot and Correlations')
plt.xlabel('relative_compactness', fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# Ovde je predstavljena zavisnost heating_load i cooling_load od relative_compactness. Mozemo primetiti da postoje jasne grupacije, clusteri podataka. U primeru koji koristimo moze se primetiti da postoji 12 grupa u koje se moze podeliti relative_compactness.

# %% [markdown]
# Pod pretpostavkom da i ostale kolone sadrze odredjene "klase" u sebi, mozemo izvuci sve unique vrednosti iz svih kolona kao brzi test.

# %% [markdown]
# #### Number of uniques per column:

# %%
for c in df.columns:
    print("Number of unique values in {}: {}".format(c, len(df[c].unique())))
# Out:
# Number of unique values in relative_compactness: 12
# Number of unique values in surface_area: 12
# Number of unique values in wall_area: 7
# Number of unique values in roof_area: 4
# Number of unique values in overall_height: 2
# Number of unique values in orientation: 4
# Number of unique values in glazing_area: 4
# Number of unique values in glazing_distribution: 6
# Number of unique values in heating_load: 586
# Number of unique values in cooling_load: 636

# %% [markdown]
# #### Unique values per column:

# %%
for c in df.columns:
    print("Unique values in {}: {}".format(c, df[c].unique()))
# Out:
# Unique values in relative_compactness: [0.98 0.9  0.86 0.82 0.79 0.76 0.74 0.71 0.69 0.66 0.64 0.62]
# Unique values in surface_area: [514.5 563.5 588.  612.5 637.  661.5 686.  710.5 735.  759.5 784.  808.5]
# Unique values in wall_area: [294.  318.5 343.  416.5 245.  269.5 367.5]
# Unique values in roof_area: [110.25 122.5  147.   220.5 ]
# Unique values in overall_height: [7.  3.5]
# Unique values in orientation: [2 3 4 5]
# Unique values in glazing_area: [0.   0.1  0.25 0.4 ]
# Unique values in glazing_distribution: [0 1 2 3 4 5]
# Unique values in heating_load: [15.55 20.84 21.46 20.71 19.68 19.5  19.95 19.34 18.31 17.05 17.41 16.95
#  15.98 28.52 29.9  29.63 28.75 24.77 23.93  6.07  6.05  6.01  6.04  6.37
#   6.4   6.85  6.79  6.77  6.81  7.18  7.1  10.85 10.54 10.77 10.56  8.6
#   8.49  8.45  8.5  24.58 24.63 24.59 29.03 29.87 29.14 28.09 26.28 26.91
#  26.37 25.27 23.53 24.03 23.54 22.58 35.56 37.12 36.9  35.94 32.96 32.12
#  32.94 32.21 10.36 10.43 10.39 10.71 10.8  10.7  10.75 11.11 11.13 11.09
#  11.16 11.68 11.69 11.7  15.41 15.2  15.42 15.21 12.96 12.97 12.93 13.02
#  24.29 24.31 24.13 24.25 28.88 29.68 28.83 27.9  26.48 27.02 26.33 25.36
#  23.75 24.23 23.67 22.79 35.65 37.26 36.97 36.03 33.16 32.4  33.12 32.41
#  10.42 10.46 10.32 10.45 10.64 10.72 10.55 10.68 11.45 11.46 11.32 11.49
#  11.42 11.33 11.43 15.18 15.34 15.19 12.88 13.   13.04 24.28 24.4  24.11
#  24.35 28.07 29.01 29.62 29.05 25.41 26.47 26.89 26.46 22.93 23.84 24.17
#  23.87 35.78 35.48 36.7  32.52 33.28 32.33 33.24 10.34 10.35 10.38 11.22
#  11.1  11.14 11.59 11.6  11.53 11.61 15.16 15.36 15.12 12.68 12.63 12.71
#  12.73 24.38 24.04 24.32 29.06 28.05 28.86 29.79 26.44 25.37 27.03 23.8
#  22.8  23.59 24.24 36.86 35.89 35.45 37.1  33.08 32.38 33.09 32.31 10.08
#  10.15 10.07 10.14 10.66 10.53 11.18 11.07 11.2  11.44 15.4  15.32 12.85
#  24.33 24.26 29.83 29.08 28.03 29.02 26.45 24.37 23.89 22.89 23.86 37.03
#  36.71 36.77 33.21 32.46 33.27 10.47 10.37 10.78 10.67 13.69 11.21 11.38
#  11.34 15.37 12.59 12.74 12.8  12.62 28.15 28.37 28.41 32.68 33.48 32.84
#  32.   29.54 30.05 29.6  28.66 26.84 27.27 26.97 26.19 38.67 40.03 39.86
#  39.04 36.96 36.13 36.91 36.43 12.43 12.5  12.41 12.45 12.57 12.65 12.78
#  12.72 13.17 13.18 17.5  17.35 17.52 17.37 15.09 15.08 28.67 28.57 28.18
#  28.6  31.66 29.34 29.27 28.4  25.74 25.98 25.38 24.94 38.57 40.19 39.97
#  38.98 36.95 36.28 36.45 12.35 12.16 12.3  12.33 12.29 12.2  12.49 12.87
#  12.95 13.05 12.77 17.14 16.84 17.02 17.11 14.34 14.66 14.6  28.56 28.17
#  28.63 31.63 32.29 29.4  29.43 29.07 24.7  25.48 25.17 38.35 39.81 39.83
#  35.99 36.59 35.64 36.52 11.8  12.03 11.98 12.28 12.1  12.19 12.34 12.46
#  12.31 12.12 13.01 12.84 16.83 16.93 16.66 16.86 13.91 13.95 13.99 28.7
#  28.55 28.62 32.67 31.69 32.07 29.47 28.42 29.88 25.66 24.96 25.43 26.
#  40.   38.84 38.33 40.12 36.81 36.26 12.32 12.18 12.36 12.17 12.91 12.67
#  12.86 12.92 16.99 16.69 16.56 16.62 14.33 14.61 14.65 28.69 28.58 28.61
#  33.13 31.53 29.71 29.09 28.31 29.39 25.7  24.6  25.49 39.89 39.01 38.65
#  35.69 36.64 36.06 11.67 11.64 12.02 12.27 12.25 12.47 12.82 16.73 16.76
#  16.92 13.68 14.16 13.86 32.26 32.49 32.53 36.47 37.24 36.66 35.96 31.89
#  32.39 32.09 31.29 29.22 29.91 29.53 28.65 41.4  42.62 42.5  41.67 40.78
#  40.71 40.43 14.52 14.5  14.55 14.51 14.58 14.7  14.42 15.23 19.52 19.36
#  19.48 19.42 17.17 32.82 32.71 32.24 32.72 35.84 36.57 32.48 32.74 32.13
#  31.64 28.95 29.49 28.64 28.01 41.64 43.1  42.74 41.92 40.15 40.57 40.42
#  14.54 14.45 14.18 14.4  14.71 14.75 14.62 15.29 15.3  19.2  18.88 18.9
#  19.12 17.23 17.26 17.15 32.69 32.23 32.75 34.24 34.95 35.05 34.29 31.28
#  32.05 31.84 29.67 28.91 41.26 41.3  42.49 42.08 39.32 39.84 38.89 39.68
#  13.97 14.22 14.1  13.78 14.07 14.03 13.94 14.32 14.56 14.08 14.72 14.9
#  18.48 18.71 18.46 16.47 16.35 16.55 16.74 32.85 35.73 35.4  32.15 28.93
#  29.52 42.77 41.73 41.32 42.96 40.68 40.4  40.6  40.11 14.37 14.48 14.44
#  14.47 14.53 19.06 19.13 19.   18.84 16.44 16.9  16.94 16.77 32.73 35.67
#  35.01 34.72 35.24 31.81 31.12 32.06 30.   29.5  29.92 42.11 41.96 41.09
#  40.79 38.82 39.72 39.31 14.41 14.19 14.17 14.39 12.76 12.42 14.12 14.28
#  14.21 14.96 14.92 17.69 18.19 18.16 17.88 16.54 16.48 16.64]
# Unique values in cooling_load: [21.33 28.28 25.38 25.16 29.6  27.3  21.97 23.49 27.87 23.77 21.46 21.16
#  24.93 37.73 31.27 30.93 39.44 29.79 29.68 29.4  10.9  11.19 10.94 11.17
#  11.27 11.72 11.29 11.67 11.74 12.05 11.73 11.93 12.4  12.23 12.14 16.78
#  16.8  16.75 16.67 12.07 12.22 12.08 12.04 26.47 26.37 26.44 26.29 32.92
#  29.87 29.58 34.33 30.89 25.6  27.03 31.73 27.31 24.91 24.61 28.51 41.68
#  35.28 34.43 43.33 33.87 34.07 34.14 33.67 13.43 13.71 13.48 13.7  13.8
#  14.28 13.87 14.27 14.61 14.3  14.45 13.9  13.72 13.88 13.65 19.37 19.43
#  19.34 19.32 14.34 14.5  14.33 25.95 25.63 26.13 25.89 32.54 29.44 29.36
#  34.2  30.91 27.36 31.9  27.38 25.02 24.8  28.79 41.07 34.62 42.86 33.91
#  34.17 33.78 13.39 13.57 13.79 13.67 14.11 14.21 13.2  13.54 13.32 13.51
#  14.86 14.75 15.   14.74 19.23 19.3  14.37 14.57 14.24 25.68 26.02 25.84
#  26.14 32.85 30.08 29.67 31.01 25.9  27.4  28.68 27.54 25.35 43.12 41.22
#  35.1  34.29 33.85 34.11 34.48 34.5  13.6  13.36 13.49 14.14 13.77 14.44
#  14.67 14.4  13.46 13.59 13.83 19.14 19.18 19.29 14.09 14.23 13.89 25.91
#  25.72 26.18 25.87 29.34 32.83 29.92 27.17 31.76 31.06 25.81 28.61 27.57
#  34.25 43.3  41.86 35.29 33.62 33.89 34.05 13.21 13.53 14.12 14.2  14.29
#  14.49 14.42 14.73 14.83 19.24 19.25 19.42 19.48 14.47 25.64 25.98 25.88
#  29.82 29.52 34.45 33.01 25.82 27.33 32.04 31.28 25.11 24.77 28.88 27.69
#  34.99 34.18 43.14 41.26 34.35 33.64 33.88 13.44 13.5  14.18 13.75 14.26
#  14.55 14.46 14.39 14.54 14.81 14.65 14.87 19.26 13.97 13.99 14.15 29.28
#  29.49 36.12 33.17 32.71 37.58 33.98 30.12 34.73 30.17 27.84 27.25 31.39
#  43.8  37.81 36.85 45.52 37.45 36.62 15.19 15.5  15.28 15.42 15.85 15.44
#  15.81 15.21 15.63 15.48 15.78 16.39 16.27 16.19 21.13 21.19 21.09 21.08
#  15.77 15.95 15.76 29.62 29.69 30.18 30.02 35.56 32.64 32.77 37.72 33.37
#  27.89 29.9  34.52 28.27 26.96 26.72 29.88 43.86 37.41 36.77 45.97 36.87
#  37.35 37.28 36.81 15.1  15.18 14.91 15.4  14.94 15.32 15.52 15.66 15.99
#  15.89 16.22 15.87 20.47 20.56 20.48 20.43 15.64 15.14 15.3  29.43 29.78
#  30.1  30.19 36.35 32.46 33.52 32.93 28.38 28.77 27.76 26.95 26.41 45.13
#  43.66 37.76 36.07 36.44 37.29 14.72 14.76 14.92 15.57 14.38 15.17 15.53
#  15.8  16.14 16.26 19.87 20.03 20.46 20.28 14.89 14.96 14.35 29.61 29.59
#  32.12 37.12 36.16 33.16 29.45 34.19 33.93 28.31 26.3  28.76 27.34 36.26
#  45.48 44.16 37.26 37.2  36.76 37.05 37.51 15.24 15.03 15.35 15.09 15.2
#  15.37 15.73 15.83 16.13 15.59 16.17 19.65 19.76 20.37 19.9  15.41 15.56
#  15.07 15.38 29.53 29.77 30.   30.2  32.25 32.   37.19 35.62 28.02 34.15
#  33.47 26.53 26.08 29.31 28.14 37.54 36.66 45.28 43.73 36.93 37.01 35.73
#  36.15 14.48 14.58 14.03 15.27 14.71 15.23 14.97 15.22 14.6  16.03 16.06
#  20.13 20.01 20.19 20.29 33.34 33.04 39.28 36.38 35.92 40.99 35.99 30.66
#  31.7  36.73 31.71 29.13 28.99 33.54 45.29 39.07 38.35 46.94 39.55 40.85
#  40.63 39.48 16.94 17.25 17.03 17.1  17.51 17.12 17.47 16.5  17.   16.87
#  17.2  18.14 18.03 17.95 22.72 22.73 22.53 17.21 17.15 32.96 33.13 33.94
#  35.39 34.94 40.66 35.48 30.53 32.28 36.86 30.34 27.93 28.95 45.59 39.41
#  38.84 48.03 40.4  40.47 39.7  16.43 16.93 16.99 16.77 17.37 17.27 16.44
#  17.01 17.23 17.22 17.85 17.89 18.36 18.15 21.72 22.07 22.09 21.93 17.36
#  17.38 16.86 32.78 33.24 33.86 34.   35.04 33.82 33.31 35.22 34.7  30.11
#  31.6  32.43 30.65 29.64 46.44 44.18 38.81 38.23 38.17 38.48 39.66 40.1
#  16.08 15.39 16.57 16.6  16.11 15.47 16.7  16.1  16.35 15.84 17.02 17.04
#  17.63 18.1  18.22 20.78 20.72 21.54 21.53 16.9  17.14 16.56 16.   32.95
#  33.06 33.95 39.92 39.22 36.1  31.53 36.2  36.21 31.   28.2  32.35 31.14
#  28.43 38.33 47.59 46.23 39.56 40.36 39.67 39.85 40.77 16.61 16.74 17.32
#  16.85 17.74 16.81 16.88 17.39 17.86 17.82 18.24 21.68 22.25 22.49 16.79
#  16.58 32.88 33.23 33.76 34.01 33.14 38.79 37.27 31.2  35.71 29.93 29.56
#  33.84 38.56 37.7  47.01 44.87 39.37 39.8  37.79 38.18 16.69 16.62 15.33
#  15.31 16.63 16.54 17.64 17.79 17.55 18.06 20.82 20.21 20.71 21.4  17.11]

# %% [markdown]
# Ovaj rezultat potvrdjuje pretpostavku da sve kolone, sem naravno output kolona heating_load i cooling_load, imaju u sebi odredjene klastere ili "klase". Drugim recima, svi nasi ulazni parametri imaju svoje podele/klase unutar sebe. Tako npr. vidimo da relative_compactness ima 12 razlicitih vrednosti, orientation 4 itd. Posto znamo da je ukupan broj redova 768, vidimo da cak i heating/cooling load imaju neke duplikate, odnosno da se neke vrednosti ponavljaju, jer nema 768 uniques.

# %% [markdown]
# Posto smo ovo videli, sada mozemo vizuelno da proverimo svaku od njih, redom od prvog do poslednjeg feature.\
# Za ovo cemo iskoristiti seaborn i hue parametar. Po x i y osama ce uvek biti output vrednosti, cooling_load i heating_load, respektivno, dok ce se raspodela i potencijalna zavisnost i grupacije videti kroz hue vrednost.

# %%
fig, ax = plt.subplots(4, 2, figsize=(20, 20))

sns.set(style='darkgrid')
sns.scatterplot(ax=ax[0][0], x=df.cooling_load, y=df.heating_load, hue=df.relative_compactness, data=df)
sns.scatterplot(ax=ax[0][1], x=df.cooling_load, y=df.heating_load, hue=df.surface_area, data=df)
sns.scatterplot(ax=ax[1][0], x=df.cooling_load, y=df.heating_load, hue=df.wall_area, data=df)
sns.scatterplot(ax=ax[1][1], x=df.cooling_load, y=df.heating_load, hue=df.roof_area, data=df)
sns.scatterplot(ax=ax[2][0], x=df.cooling_load, y=df.heating_load, hue=df.overall_height, data=df)
sns.scatterplot(ax=ax[2][1], x=df.cooling_load, y=df.heating_load, hue=df.orientation, data=df)
sns.scatterplot(ax=ax[3][0], x=df.cooling_load, y=df.heating_load, hue=df.glazing_area, data=df)
sns.scatterplot(ax=ax[3][1], x=df.cooling_load, y=df.heating_load, hue=df.glazing_distribution, data=df)

plt.show()

# %% [markdown]
# Na osnovu ovog eksperimenta mozemo primetiti da postoje odredjene grupacije ili klasteri. To su one slike gde se najjasnije moze razlikovati neka grupa tacaka, na osnovu hue vrednosti, boje. To su grafici sa sledecim atributima hue vrednosti:
# 1. **relative_compactness** (u donjem levom uglu se izdvaja grupa, koja oznacava da manje vrednosti relative_compactness-a proizvode manje vrednosti cooling i heating load)
# 2. **surface_area** (u donjem levom uglu se izdvaja grupa, koja oznacava da vece vrednosti surface_area proizvode manje vrednosti cooling i heating load)
# 3. **roof_area** (u donjem levom uglu se izdvaja grupa, koja oznacava da vece vrednosti roof_area proizvode manje vrednosti cooling i heating load)
# 4. **overall_height** (na osnovu prethodnih eksperimenata, utvrdili smo da postoje samo 2 visine koje se pominju u datasetu. Ovde se zbog toga mozda i najjasnije vide grupe. Takodje, kao i kod prethodnih, u donjem levom uglu se jasno izdvaja grupa koja ukazuje na to da za manje vrednosti overall_height imamo manje vrednosti output-a)
#
# Sve gore pomenute 4 slike imaju istu osobinu. Sve grupe su izdvojene tako da su "ogranicene" heating vrednoscu 20, i cooling vrednoscu oko 22-23.\
# Sa druge strane, heating load i cooling load u direktoj vezi, za povecanje jednog - povecava se i drugo, sto je i ocekivano.
# To mozemo pokazati na sledeci nacin.

# %%
fig, ax = plt.subplots(figsize=(10, 10))

sns.set(style='darkgrid')
sns.scatterplot(x=df.cooling_load, y=df.heating_load, data=df)

plt.show()

# %% [markdown]
# Na osnovu slike iznad, vidimo da su heating i cooling load u direktnoj vezi. Postoji skoro linearna zavisnost. Drugim recima, povecanje heating vrednosti skoro linearno utice utice na povecanje cooling vrednosti i obrnuto.

# %% [markdown]
# ### 3.3 Correlation Heatmap <a name="correlation"/>

# %% [markdown]
# Kako bismo dalje potvrdili korelaciju izmedju odredjenih atributa, mozemo iskoristiti korelacionu matricu, gde cemo prikazati sve atribute. Vrednosti se krecu od -1 do 1.
#
# **-1** - sto je vrednost bliza -1, jaca je negativna korelacija\
# **0** - vrednosti u okolini nule, znace da je korelacija slabija - ne postoji u nuli\
# **1** - sto je vrednost bliza jedinici, jaca je pozitivna korelacija

# %%
fig, ax = plt.subplots(figsize=(10, 10))
correlation_matrix = df.corr().round(2)
sns.heatmap(data=correlation_matrix, annot=True)
plt.show()

# %% [markdown]
# Na osnovu korelacione matrice mozemo izvesti neke nove zakljucke, ali i potvrditi neka prethodno pomenute pretpostavke:
# * vrednosti matrice koje su oko **0**, nemaju uticaj na heating i cooling load. Npr. mozemo videti da **orientation** ima vrednosti - **0/0.01** za heating/cooling load.
# * korelacione vrednosti izmedju **glazing_distribution** i heating/cooling load su takodje male - **0.09/0.05**
# * **glazing_area** korelaciona vrednost je malo bliza vrednosti **1**, sto znaci da postoji veoma slaba korelacija - **0.27/0.21**
# * korelacija izmedju **heating i cooling load** je **0.98**, sto potvrdjuje razmatranja iz prethodnih koraka, da su u snaznoj korelaciji
# * **overall_height** ima jaku pozitivnu korelaciju **0.89/0.9** sa obe nase target vrednosti
# * **roof_area ima** jaku negativnu korelaciju **-0.86/-0.86** sa obe nase target vrednosti
# * **relative_compactness** i **surface_area** imaju slicne vrednosti, ali suprotnog znaka. **0.62/0.63** za relative_compactness, odnosno, **-0.66/-0.67** za surface_area
# * **wall_area** ima vrednost **0.46/0.43**, sto je malo slabije u odnosu na relative compactness na primer.
#
# **orientation i glazing_distribution su u vrlo slaboj korelaciji sa output vrednostima.**

# %% [markdown]
# ## 4. Models <a name="models"/>

# %% [markdown]
# ### 4.1 Standardization and splitting <a name="standardization"/>

# %%
X = df[['relative_compactness', 
        'surface_area', 
        'wall_area', 
        'roof_area', 
        'overall_height', 
        'orientation', 
        'glazing_area', 
        'glazing_distribution']]
y = df[['heating_load']]
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3) # random_state controls the shuffling applied to the data before applying the split

# %%
# Sandardization of data
predictorScaler = StandardScaler()
targetVarScaler = StandardScaler()

# %%
# Storing the fit object for later reference
predictorScalerFit=predictorScaler.fit(X)
targetVarScalerFit=targetVarScaler.fit(y)

# %%
# Generating the standardized values of X and y
X=predictorScalerFit.transform(X)
y=targetVarScalerFit.transform(y)

# %%
# Split the data into training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
print("Ceo dataset X: {}".format(X.shape))
print("Ceo dataset Y: {}".format(y.shape))
print("X dataset za treniranje X_train: {}".format(X_train.shape))
print("X dataset za testiranje X_test: {}".format(X_test.shape))
print("Y dataset za treniranje Y_train: {}".format(y_train.shape))
print("Y dataset za testiranje Y_test: {}".format(y_test.shape))
# Out:
# Ceo dataset X: (768, 8)
# Ceo dataset Y: (768, 1)
# X dataset za treniranje X_train: (537, 8)
# X dataset za testiranje X_test: (231, 8)
# Y dataset za treniranje Y_train: (537, 1)
# Y dataset za testiranje Y_test: (231, 1)

# %% [markdown]
# ### 4.2 Model Zero <a name="model-0"/>

# %% [markdown]
# ### 4.3 Grid Search <a name="grid"/>

# %%
# Defining a function to find the best parameters for ANN
def FunctionFindBestParams(X_train, y_train, X_test, y_test):
    
    # Defining the list of hyper parameters to try
    batch_size_list=[5, 10, 15, 20]
    epoch_list = [5, 10, 50, 100]
    unit_list = [5, 8, 10, 12, 32]
    optimizer_list = ['SGD', 'RMSprop', 'Adagrad', 'Adam', 'Nadam']
    activation_list = ['relu', 'tanh', 'sigmoid', 'softmax']
    
    SearchResultsData=pd.DataFrame(columns=['TrialNumber', 'Parameters', 'Accuracy'])
    
    # initializing the trials
    TrialNumber=0
    for batch_size_trial in batch_size_list:
        for epochs_trial in epoch_list:
            for unit_trial in unit_list:
                for optimizer_trial in optimizer_list:
                    for activation_trial in activation_list:
                        TrialNumber+=1
                        # create ANN model
                        model = Sequential()
                        # Defining the first layer of the model
                        model.add(Dense(units=unit_trial, input_dim=X_train.shape[1], kernel_initializer='normal', activation=activation_trial))

                        # Defining the Second layer of the model
                        model.add(Dense(units=unit_trial, kernel_initializer='normal', activation=activation_trial))
                        model.add(Dense(units=unit_trial, kernel_initializer='normal', activation=activation_trial))
                        model.add(Dense(units=unit_trial, kernel_initializer='normal', activation=activation_trial))

                        # The output neuron is a single fully connected node 
                        # Since we will be predicting a single number
                        model.add(Dense(1, kernel_initializer='normal'))

                        # Compiling the model
                        model.compile(loss='mean_squared_error', optimizer=optimizer_trial)

                        # Fitting the ANN to the Training set
                        model.fit(X_train, y_train ,batch_size = batch_size_trial, epochs = epochs_trial, verbose=0)

                        MAPE = np.mean(100 * (np.abs(y_test-model.predict(X_test))/y_test))

                        # printing the results of the current iteration
                        print(TrialNumber, 'Parameters:',
                              'batch_size:', batch_size_trial,';', 
                              'epochs:', epochs_trial,';',
                              'unit:', unit_trial,';',
                              'optimizer:', optimizer_trial,';',
                              'activation:', activation_trial,';',
                              'Accuracy:', 100-MAPE)

                        SearchResultsData=SearchResultsData.append(pd.DataFrame(data=[[TrialNumber, 
                                                                                       str(batch_size_trial)+';'+
                                                                                       str(epochs_trial)+';'+
                                                                                       str(unit_trial)+';'+
                                                                                       str(optimizer_trial)+';'+
                                                                                       str(activation_trial),
                                                                                       100-MAPE]],
                                                                                columns=['TrialNumber', 'Parameters', 'Accuracy'] ))
    return(SearchResultsData)
 
ResultsData=FunctionFindBestParams(X_train, y_train, X_test, y_test)
# Out:
# 1 Parameters: batch_size: 5 ; epochs: 5 ; unit: 5 ; optimizer: SGD ; activation: relu ; Accuracy: 97.48375717371512
# 2 Parameters: batch_size: 5 ; epochs: 5 ; unit: 5 ; optimizer: SGD ; activation: tanh ; Accuracy: 90.70062592479874
# 3 Parameters: batch_size: 5 ; epochs: 5 ; unit: 5 ; optimizer: SGD ; activation: sigmoid ; Accuracy: 105.13635450197401
# 4 Parameters: batch_size: 5 ; epochs: 5 ; unit: 5 ; optimizer: SGD ; activation: softmax ; Accuracy: 97.3662933972673
# 5 Parameters: batch_size: 5 ; epochs: 5 ; unit: 5 ; optimizer: RMSprop ; activation: relu ; Accuracy: 95.43853164266388
# 6 Parameters: batch_size: 5 ; epochs: 5 ; unit: 5 ; optimizer: RMSprop ; activation: tanh ; Accuracy: 79.38396565249785
# 7 Parameters: batch_size: 5 ; epochs: 5 ; unit: 5 ; optimizer: RMSprop ; activation: sigmoid ; Accuracy: 91.60522296219028
# 8 Parameters: batch_size: 5 ; epochs: 5 ; unit: 5 ; optimizer: RMSprop ; activation: softmax ; Accuracy: 91.90289907590189
# 9 Parameters: batch_size: 5 ; epochs: 5 ; unit: 5 ; optimizer: Adagrad ; activation: relu ; Accuracy: 96.2382185360429
# 10 Parameters: batch_size: 5 ; epochs: 5 ; unit: 5 ; optimizer: Adagrad ; activation: tanh ; Accuracy: 97.33539466363477
# 11 Parameters: batch_size: 5 ; epochs: 5 ; unit: 5 ; optimizer: Adagrad ; activation: sigmoid ; Accuracy: 96.71838480634017
# 12 Parameters: batch_size: 5 ; epochs: 5 ; unit: 5 ; optimizer: Adagrad ; activation: softmax ; Accuracy: 99.2134835422192
# 13 Parameters: batch_size: 5 ; epochs: 5 ; unit: 5 ; optimizer: Adam ; activation: relu ; Accuracy: 60.07768901510947
# 14 Parameters: batch_size: 5 ; epochs: 5 ; unit: 5 ; optimizer: Adam ; activation: tanh ; Accuracy: 80.3768298822501
# 15 Parameters: batch_size: 5 ; epochs: 5 ; unit: 5 ; optimizer: Adam ; activation: sigmoid ; Accuracy: 90.82137046238171
# 16 Parameters: batch_size: 5 ; epochs: 5 ; unit: 5 ; optimizer: Adam ; activation: softmax ; Accuracy: 91.91249927903108
# 17 Parameters: batch_size: 5 ; epochs: 5 ; unit: 5 ; optimizer: Nadam ; activation: relu ; Accuracy: 93.18528538888646
# 18 Parameters: batch_size: 5 ; epochs: 5 ; unit: 5 ; optimizer: Nadam ; activation: tanh ; Accuracy: 76.15173846679993
# 19 Parameters: batch_size: 5 ; epochs: 5 ; unit: 5 ; optimizer: Nadam ; activation: sigmoid ; Accuracy: 94.33189276906774
# 20 Parameters: batch_size: 5 ; epochs: 5 ; unit: 5 ; optimizer: Nadam ; activation: softmax ; Accuracy: 92.34372477114253
# 21 Parameters: batch_size: 5 ; epochs: 5 ; unit: 8 ; optimizer: SGD ; activation: relu ; Accuracy: 88.9079105262322
# 22 Parameters: batch_size: 5 ; epochs: 5 ; unit: 8 ; optimizer: SGD ; activation: tanh ; Accuracy: 87.99966399391363
# 23 Parameters: batch_size: 5 ; epochs: 5 ; unit: 8 ; optimizer: SGD ; activation: sigmoid ; Accuracy: 113.52623794842361
# 24 Parameters: batch_size: 5 ; epochs: 5 ; unit: 8 ; optimizer: SGD ; activation: softmax ; Accuracy: 88.10442453253667
# 25 Parameters: batch_size: 5 ; epochs: 5 ; unit: 8 ; optimizer: RMSprop ; activation: relu ; Accuracy: 84.27019666142547
# 26 Parameters: batch_size: 5 ; epochs: 5 ; unit: 8 ; optimizer: RMSprop ; activation: tanh ; Accuracy: 73.94712899653803
# 27 Parameters: batch_size: 5 ; epochs: 5 ; unit: 8 ; optimizer: RMSprop ; activation: sigmoid ; Accuracy: 92.84457886847886
# 28 Parameters: batch_size: 5 ; epochs: 5 ; unit: 8 ; optimizer: RMSprop ; activation: softmax ; Accuracy: 91.57895648785485
# 29 Parameters: batch_size: 5 ; epochs: 5 ; unit: 8 ; optimizer: Adagrad ; activation: relu ; Accuracy: 96.15852251703832
# 30 Parameters: batch_size: 5 ; epochs: 5 ; unit: 8 ; optimizer: Adagrad ; activation: tanh ; Accuracy: 99.36102902583505
# 31 Parameters: batch_size: 5 ; epochs: 5 ; unit: 8 ; optimizer: Adagrad ; activation: sigmoid ; Accuracy: 96.07512993803712
# 32 Parameters: batch_size: 5 ; epochs: 5 ; unit: 8 ; optimizer: Adagrad ; activation: softmax ; Accuracy: 96.60645007143782
# 33 Parameters: batch_size: 5 ; epochs: 5 ; unit: 8 ; optimizer: Adam ; activation: relu ; Accuracy: 67.45808189528852
# 34 Parameters: batch_size: 5 ; epochs: 5 ; unit: 8 ; optimizer: Adam ; activation: tanh ; Accuracy: 74.03763803960479
# 35 Parameters: batch_size: 5 ; epochs: 5 ; unit: 8 ; optimizer: Adam ; activation: sigmoid ; Accuracy: 91.42489046584676
# 36 Parameters: batch_size: 5 ; epochs: 5 ; unit: 8 ; optimizer: Adam ; activation: softmax ; Accuracy: 91.8977291597722
# 37 Parameters: batch_size: 5 ; epochs: 5 ; unit: 8 ; optimizer: Nadam ; activation: relu ; Accuracy: 77.64265971413012
# 38 Parameters: batch_size: 5 ; epochs: 5 ; unit: 8 ; optimizer: Nadam ; activation: tanh ; Accuracy: 75.9406928852132
# 39 Parameters: batch_size: 5 ; epochs: 5 ; unit: 8 ; optimizer: Nadam ; activation: sigmoid ; Accuracy: 91.29713714842039
# 40 Parameters: batch_size: 5 ; epochs: 5 ; unit: 8 ; optimizer: Nadam ; activation: softmax ; Accuracy: 92.1624812691924
# 41 Parameters: batch_size: 5 ; epochs: 5 ; unit: 10 ; optimizer: SGD ; activation: relu ; Accuracy: 97.71263074443151
# 42 Parameters: batch_size: 5 ; epochs: 5 ; unit: 10 ; optimizer: SGD ; activation: tanh ; Accuracy: 92.12066698682666
# 43 Parameters: batch_size: 5 ; epochs: 5 ; unit: 10 ; optimizer: SGD ; activation: sigmoid ; Accuracy: 70.55767206497543
# 44 Parameters: batch_size: 5 ; epochs: 5 ; unit: 10 ; optimizer: SGD ; activation: softmax ; Accuracy: 85.61459262075071
# 45 Parameters: batch_size: 5 ; epochs: 5 ; unit: 10 ; optimizer: RMSprop ; activation: relu ; Accuracy: 59.484248410178644
# 46 Parameters: batch_size: 5 ; epochs: 5 ; unit: 10 ; optimizer: RMSprop ; activation: tanh ; Accuracy: 82.55412737598962
# 47 Parameters: batch_size: 5 ; epochs: 5 ; unit: 10 ; optimizer: RMSprop ; activation: sigmoid ; Accuracy: 99.24688534483353
# 48 Parameters: batch_size: 5 ; epochs: 5 ; unit: 10 ; optimizer: RMSprop ; activation: softmax ; Accuracy: 90.43117596353868
# 49 Parameters: batch_size: 5 ; epochs: 5 ; unit: 10 ; optimizer: Adagrad ; activation: relu ; Accuracy: 97.69669237532845
# 50 Parameters: batch_size: 5 ; epochs: 5 ; unit: 10 ; optimizer: Adagrad ; activation: tanh ; Accuracy: 97.03564339740662
# 51 Parameters: batch_size: 5 ; epochs: 5 ; unit: 10 ; optimizer: Adagrad ; activation: sigmoid ; Accuracy: 94.1121033688716
# 52 Parameters: batch_size: 5 ; epochs: 5 ; unit: 10 ; optimizer: Adagrad ; activation: softmax ; Accuracy: 94.6477750325155
# 53 Parameters: batch_size: 5 ; epochs: 5 ; unit: 10 ; optimizer: Adam ; activation: relu ; Accuracy: 79.61362667631128
# 54 Parameters: batch_size: 5 ; epochs: 5 ; unit: 10 ; optimizer: Adam ; activation: tanh ; Accuracy: 73.47944581802247
# 55 Parameters: batch_size: 5 ; epochs: 5 ; unit: 10 ; optimizer: Adam ; activation: sigmoid ; Accuracy: 92.77400993269987
# 56 Parameters: batch_size: 5 ; epochs: 5 ; unit: 10 ; optimizer: Adam ; activation: softmax ; Accuracy: 91.82974112030305
# 57 Parameters: batch_size: 5 ; epochs: 5 ; unit: 10 ; optimizer: Nadam ; activation: relu ; Accuracy: 93.49336492401244
# 58 Parameters: batch_size: 5 ; epochs: 5 ; unit: 10 ; optimizer: Nadam ; activation: tanh ; Accuracy: 82.28352002668868
# 59 Parameters: batch_size: 5 ; epochs: 5 ; unit: 10 ; optimizer: Nadam ; activation: sigmoid ; Accuracy: 94.8211387258561
# 60 Parameters: batch_size: 5 ; epochs: 5 ; unit: 10 ; optimizer: Nadam ; activation: softmax ; Accuracy: 93.02767698526485
# 61 Parameters: batch_size: 5 ; epochs: 5 ; unit: 12 ; optimizer: SGD ; activation: relu ; Accuracy: 102.6691348101833
# 62 Parameters: batch_size: 5 ; epochs: 5 ; unit: 12 ; optimizer: SGD ; activation: tanh ; Accuracy: 93.2970217940569
# 63 Parameters: batch_size: 5 ; epochs: 5 ; unit: 12 ; optimizer: SGD ; activation: sigmoid ; Accuracy: 77.15147264963
# 64 Parameters: batch_size: 5 ; epochs: 5 ; unit: 12 ; optimizer: SGD ; activation: softmax ; Accuracy: 92.80769185036945
# 65 Parameters: batch_size: 5 ; epochs: 5 ; unit: 12 ; optimizer: RMSprop ; activation: relu ; Accuracy: 95.81134921852112
# 66 Parameters: batch_size: 5 ; epochs: 5 ; unit: 12 ; optimizer: RMSprop ; activation: tanh ; Accuracy: 80.02221194479706
# 67 Parameters: batch_size: 5 ; epochs: 5 ; unit: 12 ; optimizer: RMSprop ; activation: sigmoid ; Accuracy: 94.73593332189252
# 68 Parameters: batch_size: 5 ; epochs: 5 ; unit: 12 ; optimizer: RMSprop ; activation: softmax ; Accuracy: 91.39413928016816
# 69 Parameters: batch_size: 5 ; epochs: 5 ; unit: 12 ; optimizer: Adagrad ; activation: relu ; Accuracy: 97.92869207821123
# 70 Parameters: batch_size: 5 ; epochs: 5 ; unit: 12 ; optimizer: Adagrad ; activation: tanh ; Accuracy: 92.79630729727398
# 71 Parameters: batch_size: 5 ; epochs: 5 ; unit: 12 ; optimizer: Adagrad ; activation: sigmoid ; Accuracy: 111.21968010822285
# 72 Parameters: batch_size: 5 ; epochs: 5 ; unit: 12 ; optimizer: Adagrad ; activation: softmax ; Accuracy: 99.24109872185407
# 73 Parameters: batch_size: 5 ; epochs: 5 ; unit: 12 ; optimizer: Adam ; activation: relu ; Accuracy: 76.01118057933601
# 74 Parameters: batch_size: 5 ; epochs: 5 ; unit: 12 ; optimizer: Adam ; activation: tanh ; Accuracy: 82.79732631059925
# 75 Parameters: batch_size: 5 ; epochs: 5 ; unit: 12 ; optimizer: Adam ; activation: sigmoid ; Accuracy: 94.27343287599354
# 76 Parameters: batch_size: 5 ; epochs: 5 ; unit: 12 ; optimizer: Adam ; activation: softmax ; Accuracy: 92.89115379862544
# 77 Parameters: batch_size: 5 ; epochs: 5 ; unit: 12 ; optimizer: Nadam ; activation: relu ; Accuracy: 73.89375311330491
# 78 Parameters: batch_size: 5 ; epochs: 5 ; unit: 12 ; optimizer: Nadam ; activation: tanh ; Accuracy: 85.01817752312424
# 79 Parameters: batch_size: 5 ; epochs: 5 ; unit: 12 ; optimizer: Nadam ; activation: sigmoid ; Accuracy: 93.13228299228084
# 80 Parameters: batch_size: 5 ; epochs: 5 ; unit: 12 ; optimizer: Nadam ; activation: softmax ; Accuracy: 92.75143357307422
# 81 Parameters: batch_size: 5 ; epochs: 5 ; unit: 32 ; optimizer: SGD ; activation: relu ; Accuracy: 80.98140322452903
# 82 Parameters: batch_size: 5 ; epochs: 5 ; unit: 32 ; optimizer: SGD ; activation: tanh ; Accuracy: 99.81913914480216
# 83 Parameters: batch_size: 5 ; epochs: 5 ; unit: 32 ; optimizer: SGD ; activation: sigmoid ; Accuracy: 124.73205233262539
# 84 Parameters: batch_size: 5 ; epochs: 5 ; unit: 32 ; optimizer: SGD ; activation: softmax ; Accuracy: 94.37777349283874
# 85 Parameters: batch_size: 5 ; epochs: 5 ; unit: 32 ; optimizer: RMSprop ; activation: relu ; Accuracy: 63.54863119856108
# 86 Parameters: batch_size: 5 ; epochs: 5 ; unit: 32 ; optimizer: RMSprop ; activation: tanh ; Accuracy: 79.59183294537816
# 87 Parameters: batch_size: 5 ; epochs: 5 ; unit: 32 ; optimizer: RMSprop ; activation: sigmoid ; Accuracy: 59.7056384304155
# 88 Parameters: batch_size: 5 ; epochs: 5 ; unit: 32 ; optimizer: RMSprop ; activation: softmax ; Accuracy: 91.55537320225936
# 89 Parameters: batch_size: 5 ; epochs: 5 ; unit: 32 ; optimizer: Adagrad ; activation: relu ; Accuracy: 79.06138280695589
# 90 Parameters: batch_size: 5 ; epochs: 5 ; unit: 32 ; optimizer: Adagrad ; activation: tanh ; Accuracy: 70.8967970889535
# 91 Parameters: batch_size: 5 ; epochs: 5 ; unit: 32 ; optimizer: Adagrad ; activation: sigmoid ; Accuracy: 96.44841632636063
# 92 Parameters: batch_size: 5 ; epochs: 5 ; unit: 32 ; optimizer: Adagrad ; activation: softmax ; Accuracy: 96.2037052409167
# 93 Parameters: batch_size: 5 ; epochs: 5 ; unit: 32 ; optimizer: Adam ; activation: relu ; Accuracy: 75.0605524016196
# 94 Parameters: batch_size: 5 ; epochs: 5 ; unit: 32 ; optimizer: Adam ; activation: tanh ; Accuracy: 79.06088233764108
# 95 Parameters: batch_size: 5 ; epochs: 5 ; unit: 32 ; optimizer: Adam ; activation: sigmoid ; Accuracy: 64.11450015758787
# 96 Parameters: batch_size: 5 ; epochs: 5 ; unit: 32 ; optimizer: Adam ; activation: softmax ; Accuracy: 92.78611738503106
# 97 Parameters: batch_size: 5 ; epochs: 5 ; unit: 32 ; optimizer: Nadam ; activation: relu ; Accuracy: 79.84740639471141
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-082e98b6f031> in <module>
#      60     return(SearchResultsData)
#      61
# ---> 62 ResultsData=FunctionFindBestParams(X_train, y_train, X_test, y_test)
#
# <ipython-input-40-082e98b6f031> in FunctionFindBestParams(X_train, y_train, X_test, y_test)
#      37
#      38                         # Fitting the ANN to the Training set
# ---> 39                         model.fit(X_train, y_train ,batch_size = batch_size_trial, epochs = epochs_trial, verbose=0)
#      40
#      41                         MAPE = np.mean(100 * (np.abs(y_test-model.predict(X_test))/y_test))
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     642         # Lifting succeeded, so variables are initialized and we can run the
#     643         # stateless function.
# --> 644         return self._stateless_fn(*args, **kwds)
#     645     else:
#     646       canon_args, canon_kwds = \
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2417     """Calls a graph function specialized to the inputs."""
#    2418     with self._lock:
# -> 2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
#    2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    2775
#    2776       self._function_cache.missed.add(call_context_key)
# -> 2777       graph_function = self._create_graph_function(args, kwargs)
#    2778       self._function_cache.primary[cache_key] = graph_function
#    2779       return graph_function, args, kwargs
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    2665             arg_names=arg_names,
#    2666             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 2667             capture_by_value=self._capture_by_value),
#    2668         self._function_attributes,
#    2669         # Tell the ConcreteFunction to clean up its graph once it goes out of
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     979         _, original_func = tf_decorator.unwrap(python_func)
#     980
# --> 981       func_outputs = python_func(*func_args, **func_kwargs)
#     982
#     983       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     439         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     440         # the function a weak reference to itself to avoid a reference cycle.
# --> 441         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     442     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     443
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     962                     recursive=True,
#     963                     optional_features=autograph_options,
# --> 964                     user_requested=True,
#     965                 ))
#     966           except Exception as e:  # pylint:disable=broad-except
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     583     try:
#     584       if kwargs is not None:
# --> 585         result = converted_f(*effective_args, **kwargs)
#     586       else:
#     587         result = converted_f(*effective_args)
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in tf__train_function(iterator)
#      11             with ag__.FunctionScope('train_function', 'fscope', ag__.ConversionOptions(recursive=True, user_requested=True, optional_features=(), internal_convert_user_code=True)) as fscope:
#      12                 data = ag__.converted_call(next, (iterator,), None, fscope)
# ---> 13                 outputs = ag__.converted_call(self.distribute_strategy.run, (self.train_step,), dict(args=(data,)), fscope)
#      14                 outputs = ag__.converted_call(reduce_per_replica, (outputs, self.distribute_strategy), dict(reduction='first'), fscope)
#      15                 try:
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     416   if conversion.is_in_whitelist_cache(f, options):
#     417     logging.log(2, 'Whitelisted %s: from cache', f)
# --> 418     return _call_unconverted(f, args, kwargs, options, False)
#     419
#     420   if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     344
#     345   if kwargs is not None:
# --> 346     return f(*args, **kwargs)
#     347   else:
#     348     return f(*args)
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in run(***failed resolving arguments***)
#     949       fn = autograph.tf_convert(
#     950           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# --> 951       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     952
#     953   # TODO(b/151224785): Remove deprecated alias.
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    2288       kwargs = {}
#    2289     with self._container_strategy().scope():
# -> 2290       return self._call_for_each_replica(fn, args, kwargs)
#    2291
#    2292   def _call_for_each_replica(self, fn, args, kwargs):
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    2647         self._container_strategy(),
#    2648         replica_id_in_sync_group=constant_op.constant(0, dtypes.int32)):
# -> 2649       return fn(*args, **kwargs)
#    2650
#    2651   def _reduce_to(self, reduce_op, value, destinations, experimental_hints):
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     260       try:
#     261         with conversion_ctx:
# --> 262           return converted_call(f, args, kwargs, options=options)
#     263       except Exception as e:  # pylint:disable=broad-except
#     264         if hasattr(e, 'ag_error_metadata'):
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     416   if conversion.is_in_whitelist_cache(f, options):
#     417     logging.log(2, 'Whitelisted %s: from cache', f)
# --> 418     return _call_unconverted(f, args, kwargs, options, False)
#     419
#     420   if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     344
#     345   if kwargs is not None:
# --> 346     return f(*args, **kwargs)
#     347   else:
#     348     return f(*args)
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in train_step(self, data)
#     539     # such as loss scaling and gradient clipping.
#     540     _minimize(self.distribute_strategy, tape, self.optimizer, loss,
# --> 541               self.trainable_variables)
#     542
#     543     self.compiled_metrics.update_state(y, y_pred, sample_weight)
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _minimize(strategy, tape, optimizer, loss, trainable_variables)
#    1810       optimizer.apply_gradients(
#    1811           zip(gradients, trainable_variables),
# -> 1812           experimental_aggregate_gradients=False)
#    1813     else:
#    1814       optimizer.apply_gradients(zip(gradients, trainable_variables))
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in apply_gradients(self, grads_and_vars, name, experimental_aggregate_gradients)
#     506           args=(grads_and_vars,),
#     507           kwargs={
# --> 508               "name": name,
#     509           })
#     510
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in merge_call(self, merge_fn, args, kwargs)
#    2418     merge_fn = autograph.tf_convert(
#    2419         merge_fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 2420     return self._merge_call(merge_fn, args, kwargs)
#    2421
#    2422   def _merge_call(self, merge_fn, args, kwargs):
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in _merge_call(self, merge_fn, args, kwargs)
#    2425         distribution_strategy_context._CrossReplicaThreadMode(self._strategy))  # pylint: disable=protected-access
#    2426     try:
# -> 2427       return merge_fn(self._strategy, *args, **kwargs)
#    2428     finally:
#    2429       _pop_per_thread_mode()
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     260       try:
#     261         with conversion_ctx:
# --> 262           return converted_call(f, args, kwargs, options=options)
#     263       except Exception as e:  # pylint:disable=broad-except
#     264         if hasattr(e, 'ag_error_metadata'):
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442         new_kwargs,
#     443         caller_fn_scope=caller_fn_scope,
# --> 444         options=options)
#     445
#     446   if inspect_utils.isbuiltin(f):
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     416   if conversion.is_in_whitelist_cache(f, options):
#     417     logging.log(2, 'Whitelisted %s: from cache', f)
# --> 418     return _call_unconverted(f, args, kwargs, options, False)
#     419
#     420   if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     344
#     345   if kwargs is not None:
# --> 346     return f(*args, **kwargs)
#     347   else:
#     348     return f(*args)
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in _distributed_apply(self, distribution, grads_and_vars, name, apply_state)
#     590                               "update_" + var.op.name, skip_on_eager=True):
#     591             update_ops.extend(distribution.extended.update(
# --> 592                 var, apply_grad_to_update_var, args=(grad,), group=False))
#     593
#     594       any_symbolic = any(isinstance(i, ops.Operation) or
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in update(self, var, fn, args, kwargs, group)
#    2011         fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    2012     with self._container_strategy().scope():
# -> 2013       return self._update(var, fn, args, kwargs, group)
#    2014
#    2015   def _update(self, var, fn, args, kwargs, group):
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in _update(self, var, fn, args, kwargs, group)
#    2657     # The implementations of _update() and _update_non_slot() are identical
#    2658     # except _update() passes `var` as the first argument to `fn()`.
# -> 2659     return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#    2660
#    2661   def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in _update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    2663     # once that value is used for something.
#    2664     with UpdateContext(colocate_with):
# -> 2665       result = fn(*args, **kwargs)
#    2666       if should_group:
#    2667         return result
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     260       try:
#     261         with conversion_ctx:
# --> 262           return converted_call(f, args, kwargs, options=options)
#     263       except Exception as e:  # pylint:disable=broad-except
#     264         if hasattr(e, 'ag_error_metadata'):
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     490
#     491   if not options.user_requested and conversion.is_whitelisted(f):
# --> 492     return _call_unconverted(f, args, kwargs, options)
#     493
#     494   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     344
#     345   if kwargs is not None:
# --> 346     return f(*args, **kwargs)
#     347   else:
#     348     return f(*args)
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in apply_grad_to_update_var(var, grad)
#     565       if "apply_state" in self._dense_apply_args:
#     566         apply_kwargs["apply_state"] = apply_state
# --> 567       update_op = self._resource_apply_dense(grad, var, **apply_kwargs)
#     568       if var.constraint is not None:
#     569         with ops.control_dependencies([update_op]):
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/keras/optimizer_v2/nadam.py in _resource_apply_dense(self, grad, var, apply_state)
#     180     v_t = (coefficients['beta_2_t'] * v +
#     181            coefficients['one_minus_beta_2_t'] * math_ops.square(grad))
# --> 182     v_t = state_ops.assign(v, v_t, use_locking=self._use_locking)
#     183     v_t_prime = v_t / coefficients['v_t_prime_denominator']
#     184     m_t_bar = (coefficients['one_minus_m_t'] * g_prime +
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/ops/state_ops.py in assign(ref, value, validate_shape, use_locking, name)
#     226         ref, value, use_locking=use_locking, name=name,
#     227         validate_shape=validate_shape)
# --> 228   return ref.assign(value, name=name)
#     229
#     230
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py in assign(self, value, use_locking, name, read_value)
#     846       self._shape.assert_is_compatible_with(value_tensor.shape)
#     847       assign_op = gen_resource_variable_ops.assign_variable_op(
# --> 848           self.handle, value_tensor, name=name)
#     849       if read_value:
#     850         return self._lazy_read(assign_op)
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/ops/gen_resource_variable_ops.py in assign_variable_op(resource, value, name)
#     152   # Add nodes to the TensorFlow graph.
#     153   _, _, _op, _outputs = _op_def_library._apply_op_helper(
# --> 154         "AssignVariableOp", resource=resource, value=value, name=name)
#     155   return _op
#     156 AssignVariableOp = tf_export("raw_ops.AssignVariableOp")(_ops.to_raw_op(assign_variable_op))
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     351   inputs = []
#     352   input_types = []
# --> 353   with g.as_default(), ops.name_scope(name) as scope:
#     354
#     355     # Perform input type inference
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py in as_default(self)
#     363     outer_cm = super(FuncGraph, self).as_default()
#     364
# --> 365     @tf_contextlib.contextmanager
#     366     def inner_cm():
#     367       """Context manager for copying distribute.Strategy scope information."""
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/util/tf_contextlib.py in contextmanager(target)
#      34   """
#      35   context_manager = _contextlib.contextmanager(target)
# ---> 36   return tf_decorator.make_decorator(target, context_manager, 'contextmanager')
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/util/tf_decorator.py in make_decorator(target, decorator_func, decorator_name, decorator_doc, decorator_argspec)
#      88     decorator_name = frame.name
#      89   decorator = TFDecorator(decorator_name, target, decorator_doc,
# ---> 90                           decorator_argspec)
#      91   setattr(decorator_func, '_tf_decorator', decorator)
#      92   # Objects that are callables (e.g., a functools.partial object) may not have
#
# ~/anaconda3/envs/mlenv/lib/python3.6/site-packages/tensorflow/python/util/tf_decorator.py in __init__(self, decorator_name, target, decorator_doc, decorator_argspec)
#     246       self.__name__ = target.__name__
#     247     if hasattr(target, '__qualname__'):
# --> 248       self.__qualname__ = target.__qualname__
#     249     if self._decorator_doc:
#     250       self.__doc__ = self._decorator_doc
#
# KeyboardInterrupt:

# %%
ResultsData.plot(x='Parameters', y='Accuracy', figsize=(15,4), kind='line')

# %% [markdown]
# Na osnovu ovog grafa vidimo da su najbolji rezultati za **batch_size=5 i epochs=5**. Naredni najbolji rezultat je **batch_size=20 i epochs=5**.

# %% [markdown]
# Sada mozemo probati treniranje sa najboljim parametrima iz grafa.

# %%
# create ANN model
model = Sequential()
 
# Defining the Input layer and FIRST hidden layer, both are same!
model.add(Dense(units=32, input_dim=8, kernel_initializer='normal', activation='relu'))
 
# Defining the Second layer of the model
# after the first layer we don't have to specify input_dim as keras configure it automatically
model.add(Dense(units=32, kernel_initializer='normal', activation='tanh'))
model.add(Dense(units=32, kernel_initializer='normal', activation='tanh'))
model.add(Dense(units=32, kernel_initializer='normal', activation='tanh'))
 
# The output neuron is a single fully connected node 
# Since we will be predicting a single number
model.add(Dense(1, kernel_initializer='normal'))
 
# Compiling the model
model.compile(loss='mean_squared_error', optimizer='adam')
 
# Fitting the ANN to the Training set
model.fit(X_train, y_train, batch_size=5, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 108/108 [==============================] - 1s 5ms/step - loss: 0.4340
# Epoch 2/100
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0935
# Epoch 3/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0821
# Epoch 4/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0775
# Epoch 5/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0761
# Epoch 6/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0730
# Epoch 7/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0714
# Epoch 8/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0749
# Epoch 9/100
# 108/108 [==============================] - 0s 2ms/step - loss: 0.0714
# Epoch 10/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0717
# Epoch 11/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0661
# Epoch 12/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0701
# Epoch 13/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0630
# Epoch 14/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0672
# Epoch 15/100
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0632
# Epoch 16/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0608
# Epoch 17/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0608
# Epoch 18/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0566
# Epoch 19/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0497
# Epoch 20/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0455
# Epoch 21/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0444
# Epoch 22/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0392
# Epoch 23/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0413
# Epoch 24/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0368
# Epoch 25/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0355
# Epoch 26/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0334
# Epoch 27/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0334
# Epoch 28/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0281
# Epoch 29/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0273
# Epoch 30/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0235
# Epoch 31/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0239
# Epoch 32/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0251
# Epoch 33/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0226
# Epoch 34/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0212
# Epoch 35/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0220
# Epoch 36/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0213
# Epoch 37/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0166
# Epoch 38/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0170
# Epoch 39/100
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0107
# Epoch 40/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0118
# Epoch 41/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0109
# Epoch 42/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0080
# Epoch 43/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0079
# Epoch 44/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 45/100
# 108/108 [==============================] - 0s 2ms/step - loss: 0.0086
# Epoch 46/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 47/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 48/100
# 108/108 [==============================] - 0s 2ms/step - loss: 0.0095
# Epoch 49/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 50/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0045
# Epoch 51/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0046
# Epoch 52/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0050
# Epoch 53/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 54/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0054
# Epoch 55/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0087
# Epoch 56/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0053
# Epoch 57/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0062
# Epoch 58/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0057
# Epoch 59/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0050
# Epoch 60/100
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0054
# Epoch 61/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0049
# Epoch 62/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 63/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0053
# Epoch 64/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0057
# Epoch 65/100
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0062
# Epoch 66/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0059
# Epoch 67/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0046
# Epoch 68/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0046
# Epoch 69/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 70/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0064
# Epoch 71/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0059
# Epoch 72/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0065
# Epoch 73/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0055
# Epoch 74/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0062
# Epoch 75/100
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0052
# Epoch 76/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0035
# Epoch 77/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 78/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 79/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 80/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0056
# Epoch 81/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 82/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0036
# Epoch 83/100
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0048
# Epoch 84/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 85/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 86/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 87/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0055
# Epoch 88/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 89/100
# 108/108 [==============================] - 0s 5ms/step - loss: 0.0054
# Epoch 90/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 91/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0040
# Epoch 92/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 93/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0037
# Epoch 94/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0049
# Epoch 95/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0043
# Epoch 96/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0044
# Epoch 97/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 98/100
# 108/108 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 99/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0044
# Epoch 100/100
# 108/108 [==============================] - 0s 4ms/step - loss: 0.0037

# %%
# Fitting the ANN to the Training set
#model.fit(X_train, y_train, batch_size = 5, epochs = 100, verbose=0)

# Generating Predictions on testing data
Predictions=model.predict(X_test)

# Scaling the predicted Price data back to original price scale
Predictions=targetVarScalerFit.inverse_transform(Predictions)

# Scaling the y_test Price data back to original price scale
y_test_orig=targetVarScalerFit.inverse_transform(y_test)

# Scaling the test data back to original scale
Test_Data=predictorScalerFit.inverse_transform(X_test)

TestingData=pd.DataFrame(data=Test_Data, columns=['relative_compactness', 
        'surface_area', 
        'wall_area', 
        'roof_area', 
        'overall_height', 
        'orientation', 
        'glazing_area', 
        'glazing_distribution'])
TestingData['load']=y_test_orig
TestingData['PredictedLoad']=Predictions
TestingData.head()
# Out:
#    relative_compactness  surface_area  wall_area  roof_area  overall_height  \
# 0                  0.62         808.5      367.5     220.50             3.5
# 1                  0.66         759.5      318.5     220.50             3.5
# 2                  0.98         514.5      294.0     110.25             7.0
# 3                  0.79         637.0      343.0     147.00             7.0
# 4                  0.64         784.0      343.0     220.50             3.5
#
#    orientation  glazing_area  glazing_distribution   load  PredictedLoad
# 0          2.0          0.40                   3.0  16.47      17.077736
# 1          2.0          0.25                   1.0  13.17      13.055633
# 2          2.0          0.40                   3.0  32.82      32.678585
# 3          4.0          0.40                   4.0  41.32      42.164486
# 4          3.0          0.25                   4.0  16.69      16.377518

# %% [markdown]
# Accuracy of the model

# %%
# Computing the absolute percent error
APE=100*(abs(TestingData['load']-TestingData['PredictedLoad'])/TestingData['load'])
TestingData['APE']=APE

print('The Accuracy of ANN model is:', 100-np.mean(APE))
TestingData.head()
# Out:
# The Accuracy of ANN model is: 97.31355368140724
#    relative_compactness  surface_area  wall_area  roof_area  overall_height  \
# 0                  0.62         808.5      367.5     220.50             3.5
# 1                  0.66         759.5      318.5     220.50             3.5
# 2                  0.98         514.5      294.0     110.25             7.0
# 3                  0.79         637.0      343.0     147.00             7.0
# 4                  0.64         784.0      343.0     220.50             3.5
#
#    orientation  glazing_area  glazing_distribution   load  PredictedLoad  \
# 0          2.0          0.40                   3.0  16.47      17.077736
# 1          2.0          0.25                   1.0  13.17      13.055633
# 2          2.0          0.40                   3.0  32.82      32.678585
# 3          4.0          0.40                   4.0  41.32      42.164486
# 4          3.0          0.25                   4.0  16.69      16.377518
#
#         APE
# 0  3.689957
# 1  0.868393
# 2  0.430880
# 3  2.043770
# 4  1.872273
